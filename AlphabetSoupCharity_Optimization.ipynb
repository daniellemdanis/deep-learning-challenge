# %%
# Importing necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Read in the charity_data.csv
url = "https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv"
charity_df = pd.read_csv(url)

# %%
# Drop non-beneficial columns
charity_df = charity_df.drop(columns=["EIN", "NAME"])

# Determine the number of unique values in each column
charity_df.nunique()

# Look at APPLICATION_TYPE value counts for binning
application_type_counts = charity_df['APPLICATION_TYPE'].value_counts()

# Determine which values to replace if counts are less than 500
replace_application = list(application_type_counts[application_type_counts < 500].index)

# Replace in DataFrame
for app in replace_application:
    charity_df.APPLICATION_TYPE = charity_df.APPLICATION_TYPE.replace(app, "Other")

# Look at CLASSIFICATION value counts for binning
classification_counts = charity_df['CLASSIFICATION'].value_counts()

# Determine which values to replace if counts are less than 1000
replace_class = list(classification_counts[classification_counts < 1000].index)

# Replace in DataFrame
for cls in replace_class:
    charity_df.CLASSIFICATION = charity_df.CLASSIFICATION.replace(cls, "Other")

# Create OneHotEncoder instance
enc = pd.get_dummies(charity_df)

# Split our preprocessed data into our features and target arrays
X = enc.drop("IS_SUCCESSFUL", axis=1).values
y = enc.IS_SUCCESSFUL.values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model
opt_model = Sequential()

# Add the first hidden layer
opt_model.add(Dense(units=128, activation='relu', input_dim=len(X_train[0])))

# Add the second hidden layer
opt_model.add(Dense(units=64, activation='relu'))

# Add the output layer
opt_model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
opt_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
opt_model.fit(X_train_scaled, y_train, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 804/804 - 2s - loss: 0.5532 - accuracy: 0.7317 - 2s/epoch - 3ms/step
# Epoch 2/100
# 804/804 - 1s - loss: 0.5499 - accuracy: 0.7331 - 1s/epoch - 2ms/step
# Epoch 3/100
# 804/804 - 1s - loss: 0.5487 - accuracy: 0.7336 - 1s/epoch - 2ms/step
# Epoch 4/100
# 804/804 - 1s - loss: 0.5479 - accuracy: 0.7347 - 1s/epoch - 2ms/step
# Epoch 5/100
# 804/804 - 1s - loss: 0.5474 - accuracy: 0.7327 - 1s/epoch - 2ms/step
# Epoch 6/100
# 804/804 - 2s - loss: 0.5469 - accuracy: 0.7349 - 2s/epoch - 3ms/step
# Epoch 7/100
# 804/804 - 1s - loss: 0.5462 - accuracy: 0.7365 - 1s/epoch - 2ms/step
# Epoch 8/100
# 804/804 - 1s - loss: 0.5455 - accuracy: 0.7362 - 1s/epoch - 2ms/step
# Epoch 9/100
# 804/804 - 2s - loss: 0.5454 - accuracy: 0.7364 - 2s/epoch - 2ms/step
# Epoch 10/100
# 804/804 - 1s - loss: 0.5443 - accuracy: 0.7356 - 1s/epoch - 2ms/step
# Epoch 11/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7377 - 1s/epoch - 2ms/step
# Epoch 12/100
# 804/804 - 1s - loss: 0.5435 - accuracy: 0.7362 - 1s/epoch - 2ms/step
# Epoch 13/100
# 804/804 - 1s - loss: 0.5433 - accuracy: 0.7378 - 1s/epoch - 2ms/step
# Epoch 14/100
# 804/804 - 1s - loss: 0.5431 - accuracy: 0.7363 - 1s/epoch - 2ms/step
# Epoch 15/100
# 804/804 - 1s - loss: 0.5426 - accuracy: 0.7374 - 1s/epoch - 2ms/step
# Epoch 16/100
# 804/804 - 1s - loss: 0.5423 - accuracy: 0.7376 - 1s/epoch - 2ms/step
# Epoch 17/100
# 804/804 - 2s - loss: 0.5419 - accuracy: 0.7368 - 2s/epoch - 3ms/step
# Epoch 18/100
# 804/804 - 2s - loss: 0.5416 - accuracy: 0.7383 - 2s/epoch - 3ms/step
# Epoch 19/100
# 804/804 - 1s - loss: 0.5416 - accuracy: 0.7378 - 1s/epoch - 2ms/step
# Epoch 20/100
# 804/804 - 1s - loss: 0.5414 - accuracy: 0.7371 - 1s/epoch - 2ms/step
# Epoch 21/100
# 804/804 - 1s - loss: 0.5411 - accuracy: 0.7382 - 1s/epoch - 2ms/step
# Epoch 22/100
# 804/804 - 1s - loss: 0.5406 - accuracy: 0.7388 - 1s/epoch - 2ms/step
# Epoch 23/100
# 804/804 - 1s - loss: 0.5407 - accuracy: 0.7393 - 1s/epoch - 2ms/step
# Epoch 24/100
# 804/804 - 1s - loss: 0.5404 - accuracy: 0.7389 - 1s/epoch - 2ms/step
# Epoch 25/100
# 804/804 - 1s - loss: 0.5398 - accuracy: 0.7386 - 1s/epoch - 2ms/step
# Epoch 26/100
# 804/804 - 2s - loss: 0.5401 - accuracy: 0.7388 - 2s/epoch - 2ms/step
# Epoch 27/100
# 804/804 - 2s - loss: 0.5395 - accuracy: 0.7400 - 2s/epoch - 2ms/step
# Epoch 28/100
# 804/804 - 1s - loss: 0.5396 - accuracy: 0.7396 - 1s/epoch - 2ms/step
# Epoch 29/100
# 804/804 - 1s - loss: 0.5399 - accuracy: 0.7386 - 1s/epoch - 2ms/step
# Epoch 30/100
# 804/804 - 1s - loss: 0.5392 - accuracy: 0.7401 - 1s/epoch - 2ms/step
# Epoch 31/100
# 804/804 - 1s - loss: 0.5392 - accuracy: 0.7398 - 1s/epoch - 2ms/step
# Epoch 32/100
# 804/804 - 1s - loss: 0.5386 - accuracy: 0.7401 - 1s/epoch - 2ms/step
# Epoch 33/100
# 804/804 - 1s - loss: 0.5393 - accuracy: 0.7398 - 1s/epoch - 2ms/step
# Epoch 34/100
# 804/804 - 1s - loss: 0.5386 - accuracy: 0.7391 - 1s/epoch - 2ms/step
# Epoch 35/100
# 804/804 - 2s - loss: 0.5388 - accuracy: 0.7397 - 2s/epoch - 2ms/step
# Epoch 36/100
# 804/804 - 1s - loss: 0.5384 - accuracy: 0.7402 - 1s/epoch - 2ms/step
# Epoch 37/100
# 804/804 - 1s - loss: 0.5386 - accuracy: 0.7399 - 1s/epoch - 2ms/step
# Epoch 38/100
# 804/804 - 1s - loss: 0.5384 - accuracy: 0.7399 - 1s/epoch - 2ms/step
# Epoch 39/100
# 804/804 - 1s - loss: 0.5379 - accuracy: 0.7409 - 1s/epoch - 2ms/step
# Epoch 40/100
# 804/804 - 1s - loss: 0.5377 - accuracy: 0.7400 - 1s/epoch - 2ms/step
# Epoch 41/100
# 804/804 - 1s - loss: 0.5378 - accuracy: 0.7401 - 1s/epoch - 2ms/step
# Epoch 42/100
# 804/804 - 1s - loss: 0.5372 - accuracy: 0.7403 - 1s/epoch - 2ms/step
# Epoch 43/100
# 804/804 - 1s - loss: 0.5370 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 44/100
# 804/804 - 2s - loss: 0.5370 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 45/100
# 804/804 - 1s - loss: 0.5370 - accuracy: 0.7386 - 1s/epoch - 2ms/step
# Epoch 46/100
# 804/804 - 1s - loss: 0.5373 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 47/100
# 804/804 - 1s - loss: 0.5367 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 48/100
# 804/804 - 1s - loss: 0.5370 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 49/100
# 804/804 - 1s - loss: 0.5361 - accuracy: 0.7402 - 1s/epoch - 2ms/step
# Epoch 50/100
# 804/804 - 1s - loss: 0.5367 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 51/100
# 804/804 - 1s - loss: 0.5369 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 52/100
# 804/804 - 1s - loss: 0.5359 - accuracy: 0.7408 - 1s/epoch - 2ms/step
# Epoch 53/100
# 804/804 - 2s - loss: 0.5367 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 54/100
# 804/804 - 2s - loss: 0.5364 - accuracy: 0.7402 - 2s/epoch - 2ms/step
# Epoch 55/100
# 804/804 - 1s - loss: 0.5361 - accuracy: 0.7403 - 1s/epoch - 2ms/step
# Epoch 56/100
# 804/804 - 1s - loss: 0.5358 - accuracy: 0.7408 - 1s/epoch - 2ms/step
# Epoch 57/100
# 804/804 - 1s - loss: 0.5356 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 58/100
# 804/804 - 1s - loss: 0.5363 - accuracy: 0.7405 - 1s/epoch - 2ms/step
# Epoch 59/100
# 804/804 - 1s - loss: 0.5351 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 60/100
# 804/804 - 1s - loss: 0.5356 - accuracy: 0.7409 - 1s/epoch - 2ms/step
# Epoch 61/100
# 804/804 - 1s - loss: 0.5357 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 62/100
# 804/804 - 2s - loss: 0.5356 - accuracy: 0.7416 - 2s/epoch - 3ms/step
# Epoch 63/100
# 804/804 - 1s - loss: 0.5354 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 64/100
# 804/804 - 1s - loss: 0.5355 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 65/100
# 804/804 - 1s - loss: 0.5355 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 66/100
# 804/804 - 1s - loss: 0.5347 - accuracy: 0.7410 - 1s/epoch - 2ms/step
# Epoch 67/100
# 804/804 - 1s - loss: 0.5352 - accuracy: 0.7418 - 1s/epoch - 2ms/step
# Epoch 68/100
# 804/804 - 1s - loss: 0.5354 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 69/100
# 804/804 - 1s - loss: 0.5351 - accuracy: 0.7409 - 1s/epoch - 2ms/step
# Epoch 70/100
# 804/804 - 1s - loss: 0.5350 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 71/100
# 804/804 - 2s - loss: 0.5349 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 72/100
# 804/804 - 2s - loss: 0.5348 - accuracy: 0.7411 - 2s/epoch - 2ms/step
# Epoch 73/100
# 804/804 - 1s - loss: 0.5351 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 74/100
# 804/804 - 1s - loss: 0.5347 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 75/100
# 804/804 - 1s - loss: 0.5348 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 76/100
# 804/804 - 1s - loss: 0.5347 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 77/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 78/100
# 804/804 - 1s - loss: 0.5346 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 79/100
# 804/804 - 1s - loss: 0.5348 - accuracy: 0.7422 - 1s/epoch - 2ms/step
# Epoch 80/100
# 804/804 - 2s - loss: 0.5343 - accuracy: 0.7413 - 2s/epoch - 2ms/step
# Epoch 81/100
# 804/804 - 1s - loss: 0.5343 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 82/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 83/100
# 804/804 - 1s - loss: 0.5342 - accuracy: 0.7410 - 1s/epoch - 2ms/step
# Epoch 84/100
# 804/804 - 1s - loss: 0.5344 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 85/100
# 804/804 - 1s - loss: 0.5339 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 86/100
# 804/804 - 1s - loss: 0.5341 - accuracy: 0.7422 - 1s/epoch - 2ms/step
# Epoch 87/100
# 804/804 - 1s - loss: 0.5342 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 88/100
# 804/804 - 1s - loss: 0.5336 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 89/100
# 804/804 - 2s - loss: 0.5340 - accuracy: 0.7410 - 2s/epoch - 2ms/step
# Epoch 90/100
# 804/804 - 1s - loss: 0.5337 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 91/100
# 804/804 - 1s - loss: 0.5345 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 92/100
# 804/804 - 1s - loss: 0.5334 - accuracy: 0.7420 - 1s/epoch - 2ms/step
# Epoch 93/100
# 804/804 - 1s - loss: 0.5342 - accuracy: 0.7419 - 1s/epoch - 2ms/step
# Epoch 94/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 95/100
# 804/804 - 1s - loss: 0.5339 - accuracy: 0.7405 - 1s/epoch - 2ms/step
# Epoch 96/100
# 804/804 - 1s - loss: 0.5340 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 97/100
# 804/804 - 1s - loss: 0.5338 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 98/100
# 804/804 - 2s - loss: 0.5333 - accuracy: 0.7422 - 2s/epoch - 2ms/step
# Epoch 99/100
# 804/804 - 1s - loss: 0.5335 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 100/100
# 804/804 - 1s - loss: 0.5337 - accuracy: 0.7418 - 1s/epoch - 2ms/step

# %%
# Save the model to an HDF5 file
opt_model.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
